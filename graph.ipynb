# %%
import numpy as np
import matplotlib.pyplot as plt
n = 1000000
t = np.logspace(np.log10(10),np.log10(500),n)

A = [  1.5, 1.5, 1.5, 1.5 ]
d = [ .014, .0012, .0022, .00155 ]
f = [   1, 3, 4, 1 ]

x = A[0]*np.sin(t*f[0])*np.exp(-d[0]*t) + A[1]*np.sin(t*f[1])*np.exp(-d[1]*t)
y = A[2]*np.sin(t*f[2])*np.exp(-d[2]*t) + A[3]*np.sin(t*f[3])*np.exp(-d[3]*t)

plt.plot(x,y,'k',linewidth=.1, color="blue")
plt.axis('off')
plt.show()

# %%
n = 2000000
t = np.logspace(np.log10(10), np.log10(1500), n)
A = [2.0, 2.0, 2.1, 1.9]
d = [0.004, 0.006, 0.008, 0.01]
f = [3, 2, 12, 7]

x = A[0]*np.sin(t*f[0])*np.exp(-d[0]*t) + A[1]*np.sin(t*f[1])*np.exp(-d[1]*t)
y = A[2]*np.sin(t*f[2])*np.exp(-d[2]*t) + A[3]*np.sin(t*f[3])*np.exp(-d[3]*t)

plt.figure(figsize=(8, 8))
plt.plot(x, y, 'k', linewidth=0.05, color="purple")
plt.axis('off')
plt.show()
